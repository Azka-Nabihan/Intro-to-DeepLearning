# %% [markdown]
# # Regression Models with Keras

# %% [markdown]
# ## Introduction

# %% [markdown]
# As we discussed in the videos, despite the popularity of more powerful libraries such as PyToch and TensorFlow, they are not easy to use and have a steep learning curve. So, for people who are just starting to learn deep learning, there is no better library to use other than the Keras library.
#
# Keras is a high-level API for building deep learning models. It has gained favor for its ease of use and syntactic simplicity facilitating fast development. As you will see in this lab and the other labs in this course, building a very complex deep learning network can be achieved with Keras with only few lines of code. You will appreciate Keras even more, once you learn how to build deep models using PyTorch and TensorFlow in the other courses.
#
# So, in this lab, you will learn how to use the Keras library to build a regression model.

# %% [markdown]
# ## Objectives for this Notebook
# * How to use the Keras library to build a regression model
# * Download and clean the data set
# * Build a neural network
# * Train and test the network

# %% [markdown]
# <h2>Table of Contents</h2>
#
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 4>
# 1. <a href="#Download-and-Clean-the-Data-Set">Download and Clean the Data Set</a><br>
# 2. <a href="#Import-Keras-Packages">Import Keras Packages</a><br>
# 3. <a href="#Build-a-Neural-Network">Build a Neural Network</a><br>
# 4. <a href="#Train-and-Test-the-Network">Train and Test the Network</a><br>
#
# </font>
# </div>

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
# !pip install numpy==1.26.4
# !pip install pandas==2.2.2
# !pip install tensorflow_cpu==2.18.0
# Out:
# Collecting numpy==1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 1.26.4 which is incompatible.
#   Obtaining dependency information for numpy==1.26.4 from https://files.pythonhosted.org/packages/3f/6b/5610004206cf7f8e7ad91c5a85a8c71b2f2f8051a0c0c4d5916b76d6cbb2/numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/61.0 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 651.3 kB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.8 MB 5.7 MB/s eta 0:00:03
#    - -------------------------------------- 0.7/15.8 MB 7.9 MB/s eta 0:00:02
#    --- ------------------------------------ 1.2/15.8 MB 8.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.7/15.8 MB 10.0 MB/s eta 0:00:02
#    ------ --------------------------------- 2.4/15.8 MB 10.3 MB/s eta 0:00:02
#    ------- -------------------------------- 3.0/15.8 MB 11.1 MB/s eta 0:00:02
#    --------- ------------------------------ 3.8/15.8 MB 12.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 4.5/15.8 MB 12.6 MB/s eta 0:00:01
#    ------------- -------------------------- 5.2/15.8 MB 12.4 MB/s eta 0:00:01
#    -------------- ------------------------- 5.9/15.8 MB 12.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.6/15.8 MB 12.7 MB/s eta 0:00:01
#    ------------------ --------------------- 7.2/15.8 MB 13.1 MB/s eta 0:00:01
#    -------------------- ------------------- 8.0/15.8 MB 13.1 MB/s eta 0:00:01
#    --------------------- ------------------ 8.7/15.8 MB 13.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.4/15.8 MB 13.7 MB/s eta 0:00:01
#    ------------------------- -------------- 9.9/15.8 MB 13.5 MB/s eta 0:00:01
#    -------------------------- ------------- 10.4/15.8 MB 13.6 MB/s eta 0:00:01
#    --------------------------- ------------ 10.9/15.8 MB 13.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.5/15.8 MB 13.9 MB/s eta 0:00:01
#    ------------------------------ --------- 12.1/15.8 MB 13.9 MB/s eta 0:00:01
#    -------------------------------- ------- 12.7/15.8 MB 13.9 MB/s eta 0:00:01
#    -------------------------------- ------- 12.9/15.8 MB 13.4 MB/s eta 0:00:01
#    --------------------------------- ------ 13.4/15.8 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.8/15.8 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------ --- 14.3/15.8 MB 12.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.8 MB 12.1 MB/s eta 0:00:01
#    -------------------------------------- - 15.3/15.8 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 10.7 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# Successfully installed numpy-1.26.4
# Requirement already satisfied: pandas==2.2.2 in c:\users\azkan\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\azkan\anaconda3\lib\site-packages (from pandas==2.2.2) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\azkan\appdata\roaming\python\python311\site-packages (from pandas==2.2.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\azkan\anaconda3\lib\site-packages (from pandas==2.2.2) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\azkan\anaconda3\lib\site-packages (from pandas==2.2.2) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\azkan\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.16.0)
# Requirement already satisfied: tensorflow_cpu==2.18.0 in c:\users\azkan\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow_cpu==2.18.0) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.4.0)
# Requirement already satisfied: packaging in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.76.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.13.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.15.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\azkan\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\azkan\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.38.4)
# Requirement already satisfied: rich in c:\users\azkan\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (14.2.0)
# Requirement already satisfied: namex in c:\users\azkan\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.1.0)
# Requirement already satisfied: optree in c:\users\azkan\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\azkan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\azkan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\azkan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\azkan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\azkan\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\azkan\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\azkan\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\azkan\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\azkan\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\azkan\appdata\roaming\python\python311\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\azkan\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.1.0)

# %% [markdown]
# #### To use Keras, you will also need to install a backend framework – such as TensorFlow.
#
# If you install TensorFlow 2.16 or above, it will install Keras by default.
#
# We are using the CPU version of tensorflow since we are dealing with smaller datasets.
# You may install the GPU version of tensorflow on your machine to accelarate the processing of larger datasets

# %% [markdown]
# #### Suppress the tensorflow warning messages
# We use the following code to  suppress the warning messages due to use of CPU architechture for tensoflow.
#
# You may want to **comment out** these lines if you are using the GPU architechture

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import pandas as pd
import numpy as np
import keras

import warnings
warnings.simplefilter('ignore', FutureWarning)
# Out:
# c:\Users\azkan\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# c:\Users\azkan\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# * Cement
# * Blast furnace slag
# * Fly ash
# * Water
# * Superplasticizer
# * Coarse aggregate
# * Fine aggregate

# %% [markdown]
# ## Download and Clean the Data Set

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
filepath='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(filepath)

concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

# %%
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# ##  Import Keras Packages
#
# ##### Let's import the rest of the packages from the Keras library that we will need to build our regression model.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - 43ms/step - loss: 1645.4579 - val_loss: 1137.8156
# Epoch 2/100
# 23/23 - 0s - 5ms/step - loss: 1507.3602 - val_loss: 1012.2374
# Epoch 3/100
# 23/23 - 0s - 5ms/step - loss: 1307.4891 - val_loss: 827.3350
# Epoch 4/100
# 23/23 - 0s - 4ms/step - loss: 1020.7640 - val_loss: 594.3513
# Epoch 5/100
# 23/23 - 0s - 5ms/step - loss: 688.8804 - val_loss: 363.6806
# Epoch 6/100
# 23/23 - 0s - 4ms/step - loss: 426.4318 - val_loss: 224.2455
# Epoch 7/100
# 23/23 - 0s - 4ms/step - loss: 293.0595 - val_loss: 187.3081
# Epoch 8/100
# 23/23 - 0s - 5ms/step - loss: 253.5451 - val_loss: 181.2749
# Epoch 9/100
# 23/23 - 0s - 5ms/step - loss: 230.8620 - val_loss: 181.6780
# Epoch 10/100
# 23/23 - 0s - 5ms/step - loss: 217.0727 - val_loss: 181.1025
# Epoch 11/100
# 23/23 - 0s - 4ms/step - loss: 206.5571 - val_loss: 178.6407
# Epoch 12/100
# 23/23 - 0s - 5ms/step - loss: 198.7496 - val_loss: 178.4785
# Epoch 13/100
# 23/23 - 0s - 4ms/step - loss: 190.2126 - val_loss: 174.3716
# Epoch 14/100
# 23/23 - 0s - 4ms/step - loss: 185.0584 - val_loss: 173.3354
# Epoch 15/100
# 23/23 - 0s - 4ms/step - loss: 178.8185 - val_loss: 170.7599
# Epoch 16/100
# 23/23 - 0s - 4ms/step - loss: 174.4675 - val_loss: 170.0015
# Epoch 17/100
# 23/23 - 0s - 4ms/step - loss: 170.8061 - val_loss: 169.5788
# Epoch 18/100
# 23/23 - 0s - 4ms/step - loss: 166.4935 - val_loss: 168.0652
# Epoch 19/100
# 23/23 - 0s - 12ms/step - loss: 163.8957 - val_loss: 169.4753
# Epoch 20/100
# 23/23 - 0s - 4ms/step - loss: 159.9470 - val_loss: 167.9261
# Epoch 21/100
# 23/23 - 0s - 4ms/step - loss: 157.6269 - val_loss: 165.2991
# Epoch 22/100
# 23/23 - 0s - 4ms/step - loss: 155.2298 - val_loss: 165.8408
# Epoch 23/100
# 23/23 - 0s - 5ms/step - loss: 153.9142 - val_loss: 166.0303
# Epoch 24/100
# 23/23 - 0s - 4ms/step - loss: 151.7762 - val_loss: 166.3140
# Epoch 25/100
# 23/23 - 0s - 4ms/step - loss: 149.1963 - val_loss: 165.4910
# Epoch 26/100
# Epoch 90/100
# 23/23 - 0s - 4ms/step - loss: 38.5336 - val_loss: 164.9894
# Epoch 91/100
# 23/23 - 0s - 4ms/step - loss: 37.4972 - val_loss: 152.5550
# Epoch 92/100
# 23/23 - 0s - 4ms/step - loss: 37.1965 - val_loss: 150.5420
# Epoch 93/100
# 23/23 - 0s - 4ms/step - loss: 36.5432 - val_loss: 153.8462
# Epoch 94/100
# 23/23 - 0s - 4ms/step - loss: 36.5198 - val_loss: 153.0817
# Epoch 95/100
# 23/23 - 0s - 4ms/step - loss: 36.5985 - val_loss: 157.2564
# Epoch 96/100
# 23/23 - 0s - 4ms/step - loss: 35.9843 - val_loss: 154.4244
# Epoch 97/100
# 23/23 - 0s - 4ms/step - loss: 35.6465 - val_loss: 152.1710
# Epoch 98/100
# 23/23 - 0s - 4ms/step - loss: 35.4781 - val_loss: 150.3437
# Epoch 99/100
# 23/23 - 0s - 4ms/step - loss: 34.9566 - val_loss: 155.6922
# Epoch 100/100
# 23/23 - 0s - 4ms/step - loss: 34.6336 - val_loss: 152.7661

# %% [markdown]
# <strong>You can refer to this [link](https://keras.io/models/sequential/) to learn about other functions that you can use for prediction or evaluation.</strong>

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# <h3>Practice Exercise 1</h3>

# %% [markdown]
# Now using the same dateset,try to recreate regression model featuring five hidden layers, each with 50 nodes and ReLU activation functions, a single output layer, optimized using the Adam optimizer.

# %%
def regression_model():
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# <h3>Practice Exercise 2</h3>

# %% [markdown]
#  Train and evaluate the model simultaneously using the fit() method by reserving 10% of the data for validation and training the model for 100 epochs

# %%
# Write your code here
model = regression_model()

model.fit(predictors_norm, target, validation_split=0.1, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 29/29 - 2s - 53ms/step - loss: 1528.5568 - val_loss: 1027.1459
# Epoch 2/100
# 29/29 - 0s - 4ms/step - loss: 889.8922 - val_loss: 310.5486
# Epoch 3/100
# 29/29 - 0s - 5ms/step - loss: 309.5018 - val_loss: 213.4910
# Epoch 4/100
# 29/29 - 0s - 5ms/step - loss: 230.5169 - val_loss: 173.5586
# Epoch 5/100
# 29/29 - 0s - 4ms/step - loss: 211.7215 - val_loss: 165.9301
# Epoch 6/100
# 29/29 - 0s - 5ms/step - loss: 191.7938 - val_loss: 153.2373
# Epoch 7/100
# 29/29 - 0s - 5ms/step - loss: 175.9341 - val_loss: 142.9007
# Epoch 8/100
# 29/29 - 0s - 5ms/step - loss: 163.9728 - val_loss: 141.8611
# Epoch 9/100
# 29/29 - 0s - 5ms/step - loss: 151.9566 - val_loss: 130.9663
# Epoch 10/100
# 29/29 - 0s - 6ms/step - loss: 138.5796 - val_loss: 125.4019
# Epoch 11/100
# 29/29 - 0s - 5ms/step - loss: 128.5267 - val_loss: 116.7863
# Epoch 12/100
# 29/29 - 0s - 6ms/step - loss: 119.3807 - val_loss: 103.7185
# Epoch 13/100
# 29/29 - 0s - 6ms/step - loss: 106.0372 - val_loss: 102.2428
# Epoch 14/100
# 29/29 - 0s - 5ms/step - loss: 96.9225 - val_loss: 96.7219
# Epoch 15/100
# 29/29 - 0s - 5ms/step - loss: 87.7615 - val_loss: 79.0177
# Epoch 16/100
# 29/29 - 0s - 5ms/step - loss: 82.2470 - val_loss: 81.7944
# Epoch 17/100
# 29/29 - 0s - 4ms/step - loss: 76.7752 - val_loss: 78.2580
# Epoch 18/100
# 29/29 - 0s - 4ms/step - loss: 70.6742 - val_loss: 78.1272
# Epoch 19/100
# 29/29 - 0s - 5ms/step - loss: 66.4908 - val_loss: 76.7695
# Epoch 20/100
# 29/29 - 0s - 4ms/step - loss: 65.4043 - val_loss: 61.8301
# Epoch 21/100
# 29/29 - 0s - 4ms/step - loss: 58.5281 - val_loss: 70.9120
# Epoch 22/100
# 29/29 - 0s - 4ms/step - loss: 54.0086 - val_loss: 70.5849
# Epoch 23/100
# 29/29 - 0s - 4ms/step - loss: 52.4531 - val_loss: 66.3171
# Epoch 24/100
# 29/29 - 0s - 4ms/step - loss: 50.4230 - val_loss: 56.1989
# Epoch 25/100
# 29/29 - 0s - 4ms/step - loss: 49.0446 - val_loss: 59.1229
# Epoch 26/100
# 29/29 - 0s - 4ms/step - loss: 44.9986 - val_loss: 59.8784
# Epoch 27/100
# 29/29 - 0s - 4ms/step - loss: 43.0535 - val_loss: 54.8946
# Epoch 28/100
# 29/29 - 0s - 4ms/step - loss: 41.8339 - val_loss: 43.3124
# Epoch 29/100
# 29/29 - 0s - 6ms/step - loss: 40.6375 - val_loss: 52.6528
# Epoch 30/100
# 29/29 - 0s - 4ms/step - loss: 41.4836 - val_loss: 48.3629
# Epoch 31/100
# 29/29 - 0s - 4ms/step - loss: 37.0280 - val_loss: 43.2101
# Epoch 32/100
# 29/29 - 0s - 4ms/step - loss: 35.7241 - val_loss: 48.4634
# Epoch 33/100
# 29/29 - 0s - 4ms/step - loss: 35.7625 - val_loss: 39.4739
# Epoch 34/100
# 29/29 - 0s - 4ms/step - loss: 34.0638 - val_loss: 43.8866
# Epoch 35/100
# 29/29 - 0s - 4ms/step - loss: 34.7456 - val_loss: 36.6207
# Epoch 36/100
# 29/29 - 0s - 4ms/step - loss: 33.2878 - val_loss: 49.9609
# Epoch 37/100
# 29/29 - 0s - 4ms/step - loss: 32.7190 - val_loss: 41.3885
# Epoch 38/100
# 29/29 - 0s - 4ms/step - loss: 30.9140 - val_loss: 35.9901
# Epoch 39/100
# 29/29 - 0s - 4ms/step - loss: 31.2911 - val_loss: 41.0580
# Epoch 40/100
# 29/29 - 0s - 4ms/step - loss: 30.4413 - val_loss: 40.2910
# Epoch 41/100
# 29/29 - 0s - 4ms/step - loss: 30.8393 - val_loss: 31.1346
# Epoch 42/100
# 29/29 - 0s - 4ms/step - loss: 31.1496 - val_loss: 33.3651
# Epoch 43/100
# 29/29 - 0s - 4ms/step - loss: 29.3466 - val_loss: 35.2271
# Epoch 44/100
# 29/29 - 0s - 4ms/step - loss: 28.2438 - val_loss: 35.3813
# Epoch 45/100
# 29/29 - 0s - 4ms/step - loss: 28.7068 - val_loss: 32.5622
# Epoch 46/100
# 29/29 - 0s - 4ms/step - loss: 28.4655 - val_loss: 31.8538
# Epoch 47/100
# 29/29 - 0s - 4ms/step - loss: 26.7771 - val_loss: 34.6589
# Epoch 48/100
# 29/29 - 0s - 4ms/step - loss: 27.4590 - val_loss: 34.0541
# Epoch 49/100
# 29/29 - 0s - 4ms/step - loss: 26.0138 - val_loss: 31.2138
# Epoch 50/100
# 29/29 - 0s - 4ms/step - loss: 26.1043 - val_loss: 32.0282
# Epoch 51/100
# 29/29 - 0s - 4ms/step - loss: 26.6195 - val_loss: 30.1951
# Epoch 52/100
# 29/29 - 0s - 5ms/step - loss: 25.8286 - val_loss: 32.5557
# Epoch 53/100
# 29/29 - 0s - 4ms/step - loss: 25.8751 - val_loss: 38.9931
# Epoch 54/100
# 29/29 - 0s - 4ms/step - loss: 25.8808 - val_loss: 30.4802
# Epoch 55/100
# 29/29 - 0s - 4ms/step - loss: 24.6680 - val_loss: 34.1314
# Epoch 56/100
# 29/29 - 0s - 4ms/step - loss: 24.1750 - val_loss: 27.8299
# Epoch 57/100
# 29/29 - 0s - 4ms/step - loss: 23.9336 - val_loss: 31.0110
# Epoch 58/100
# 29/29 - 0s - 4ms/step - loss: 23.5926 - val_loss: 33.9028
# Epoch 59/100
# 29/29 - 0s - 4ms/step - loss: 22.8060 - val_loss: 31.3867
# Epoch 60/100
# 29/29 - 0s - 4ms/step - loss: 23.3658 - val_loss: 31.0179
# Epoch 61/100
# 29/29 - 0s - 4ms/step - loss: 22.6652 - val_loss: 33.1266
# Epoch 62/100
# 29/29 - 0s - 4ms/step - loss: 23.5552 - val_loss: 30.1207
# Epoch 63/100
# 29/29 - 0s - 4ms/step - loss: 22.1353 - val_loss: 34.5199
# Epoch 64/100
# 29/29 - 0s - 4ms/step - loss: 22.4072 - val_loss: 27.5200
# Epoch 65/100
# 29/29 - 0s - 4ms/step - loss: 21.2045 - val_loss: 30.9745
# Epoch 66/100
# 29/29 - 0s - 4ms/step - loss: 22.4332 - val_loss: 27.5460
# Epoch 67/100
# 29/29 - 0s - 4ms/step - loss: 21.0678 - val_loss: 30.7803
# Epoch 68/100
# 29/29 - 0s - 4ms/step - loss: 20.0664 - val_loss: 31.7608
# Epoch 69/100
# 29/29 - 0s - 4ms/step - loss: 21.1917 - val_loss: 28.9449
# Epoch 70/100
# 29/29 - 0s - 4ms/step - loss: 20.5320 - val_loss: 29.3312
# Epoch 71/100
# 29/29 - 0s - 4ms/step - loss: 19.4965 - val_loss: 29.6957
# Epoch 72/100
# 29/29 - 0s - 4ms/step - loss: 20.0864 - val_loss: 33.2867
# Epoch 73/100
# 29/29 - 0s - 4ms/step - loss: 21.7162 - val_loss: 27.8784
# Epoch 74/100
# 29/29 - 0s - 5ms/step - loss: 19.7444 - val_loss: 27.3927
# Epoch 75/100
# 29/29 - 0s - 4ms/step - loss: 18.9769 - val_loss: 27.3967
# Epoch 76/100
# 29/29 - 0s - 4ms/step - loss: 18.7183 - val_loss: 24.8629
# Epoch 77/100
# 29/29 - 0s - 4ms/step - loss: 19.3253 - val_loss: 26.4996
# Epoch 78/100
# 29/29 - 0s - 4ms/step - loss: 18.9769 - val_loss: 25.5632
# Epoch 79/100
# 29/29 - 0s - 4ms/step - loss: 18.8925 - val_loss: 26.1509
# Epoch 80/100
# 29/29 - 0s - 4ms/step - loss: 17.6871 - val_loss: 25.7189
# Epoch 81/100
# 29/29 - 0s - 4ms/step - loss: 17.8106 - val_loss: 26.4789
# Epoch 82/100
# 29/29 - 0s - 4ms/step - loss: 17.7037 - val_loss: 25.1561
# Epoch 83/100
# 29/29 - 0s - 4ms/step - loss: 17.7493 - val_loss: 25.5893
# Epoch 84/100
# 29/29 - 0s - 4ms/step - loss: 17.7635 - val_loss: 24.4092
# Epoch 85/100
# 29/29 - 0s - 4ms/step - loss: 17.7200 - val_loss: 23.2718
# Epoch 86/100
# 29/29 - 0s - 4ms/step - loss: 16.8368 - val_loss: 24.2171
# Epoch 87/100
# 29/29 - 0s - 4ms/step - loss: 16.4812 - val_loss: 24.4937
# Epoch 88/100
# 29/29 - 0s - 4ms/step - loss: 16.4908 - val_loss: 29.9201
# Epoch 89/100
# 29/29 - 0s - 4ms/step - loss: 16.3415 - val_loss: 29.3467
# Epoch 90/100
# 29/29 - 0s - 4ms/step - loss: 16.0074 - val_loss: 23.5846
# Epoch 91/100
# 29/29 - 0s - 4ms/step - loss: 16.4842 - val_loss: 27.4805
# Epoch 92/100
# 29/29 - 0s - 4ms/step - loss: 16.0421 - val_loss: 24.4464
# Epoch 93/100
# 29/29 - 0s - 4ms/step - loss: 16.5074 - val_loss: 23.8926
# Epoch 94/100
# 29/29 - 0s - 4ms/step - loss: 17.3658 - val_loss: 24.7549
# Epoch 95/100
# 29/29 - 0s - 4ms/step - loss: 16.5563 - val_loss: 23.3453
# Epoch 96/100
# 29/29 - 0s - 4ms/step - loss: 15.7445 - val_loss: 26.6034
# Epoch 97/100
# 29/29 - 0s - 4ms/step - loss: 16.1431 - val_loss: 23.6412
# Epoch 98/100
# 29/29 - 0s - 4ms/step - loss: 15.6206 - val_loss: 24.1814
# Epoch 99/100
# 29/29 - 0s - 4ms/step - loss: 15.0532 - val_loss: 25.3776
# Epoch 100/100
# 29/29 - 0s - 4ms/step - loss: 15.6192 - val_loss: 22.5279

# %% [markdown]
# Based on the results, we notice that:
#
# - Adding more hidden layers to the model increases its capacity to learn and represent complex relationships within the data. This allows the model to better identify, as a result, the model becomes more effective at fitting the training data and potentially improving its predictions.
# - By reducing the proportion of data set aside for validation and using a larger portion for training, the model has access to more examples to learn from. This additional training data helps the model improve its understanding of the underlying trends, which can lead to better overall performance.

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 3.0  | Aman  |  Updated the library versions to current |
# | 2020-09-21  | 2.0  | Srishti  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>
